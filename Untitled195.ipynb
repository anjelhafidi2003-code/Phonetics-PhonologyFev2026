# %% [markdown]
# <a href="https://colab.research.google.com/github/Behnooshn/Phonetics-PhonologyFev2026/blob/main/Untitled195.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **install + build whisper.cpp (https://github.com/ggml-org/whisper.cpp**)

# %%
import os, subprocess, textwrap, sys

def run(cmd):
    print(" ".join(cmd))
    subprocess.run(cmd, check=True)

# system deps
run(["apt-get","-qq","update"])
run(["apt-get","-qq","install","-y","ffmpeg","cmake","build-essential","git"])

# clone + build
os.chdir("/content")
if not os.path.exists("whisper.cpp"):
    run(["git","clone","https://github.com/ggml-org/whisper.cpp"])
os.chdir("/content/whisper.cpp")

run(["cmake","-B","build"])
run(["cmake","--build","build","-j"])
# Out:
# apt-get -qq update
# apt-get -qq install -y ffmpeg cmake build-essential git
# cmake -B build
# cmake --build build -j

# %% [markdown]
#  **download a multilingual model (could be base, small, medium, large)
# !Attention: large model may crash Google Colab**

# %%
import os, subprocess

def run(cmd):
    print(" ".join(cmd))
    subprocess.run(cmd, check=True)


os.chdir("/content/whisper.cpp")
run(["bash","./models/download-ggml-model.sh","small"])  # You can change the model
# Out:
# bash ./models/download-ggml-model.sh small

# %% [markdown]
# **ensure WAV format (16k mono)**

# %%
import subprocess

WAV_IN  = "/content/005-A.wav"         #change the file path
WAV_16K = "/content/audio_16k.wav"

subprocess.run([
    "ffmpeg","-y","-i",WAV_IN,
    "-ar","16000","-ac","1","-c:a","pcm_s16le",
    WAV_16K
], check=True)
# Out:
# CompletedProcess(args=['ffmpeg', '-y', '-i', '/content/005-A.wav', '-ar', '16000', '-ac', '1', '-c:a', 'pcm_s16le', '/content/audio_16k.wav'], returncode=0)

# %% [markdown]
# **Transcribe + get tokens + (experimental) token timestamps + probs**

# %%
import os, subprocess, json

os.chdir("/content/whisper.cpp")

MODEL = "models/ggml-small.bin"     #Be sure the model matches the one you selected in the previous cell.
AUDIO = "/content/audio_16k.wav"
OUT   = "/content/out"

subprocess.run([
    "./build/bin/whisper-cli",
    "-m", MODEL,
    "-f", AUDIO,
    "-l", "auto",        # or "fr", "ar", ...
    "-ojf",
    "-dtw", "base",
    "-of", OUT
], check=True)

j = json.load(open("/content/out.json","r",encoding="utf-8"))

rows = []
for seg in j.get("transcription", []):
    for tok in seg.get("tokens", []):
        offs = tok.get("offsets", {})  # ms, when available
        rows.append({
            "token": tok.get("text"),
            "start_ms": offs.get("from"),
            "end_ms": offs.get("to"),
            "p": tok.get("p"),
            "id": tok.get("id"),
        })

__import__("pandas").DataFrame(rows).to_csv("/content/tokens.csv", index=False)

# print first tokens
for r in rows[:40]:
    print(r)
# Out:
# {'token': '[_BEG_]', 'start_ms': 0, 'end_ms': 0, 'p': 0.911512, 'id': 50364}
# {'token': ' آ', 'start_ms': 140, 'end_ms': 140, 'p': 0.197326, 'id': 19753}
# {'token': 'ن', 'start_ms': 150, 'end_ms': 280, 'p': 0.966877, 'id': 1863}
# {'token': 'چ', 'start_ms': 280, 'end_ms': 280, 'p': 0.586793, 'id': 24061}
# {'token': 'ه', 'start_ms': 560, 'end_ms': 560, 'p': 0.918892, 'id': 3224}
# {'token': ' ا', 'start_ms': 560, 'end_ms': 700, 'p': 0.954076, 'id': 1975}
# {'token': 'مر', 'start_ms': 700, 'end_ms': 990, 'p': 0.587997, 'id': 29973}
# {'token': 'و', 'start_ms': 990, 'end_ms': 1130, 'p': 0.976008, 'id': 2407}
# {'token': 'ز', 'start_ms': 1130, 'end_ms': 1260, 'p': 0.887625, 'id': 11622}
# {'token': ' م', 'start_ms': 1270, 'end_ms': 1410, 'p': 0.943561, 'id': 3714}
# {'token': 'م', 'start_ms': 1410, 'end_ms': 1540, 'p': 0.628709, 'id': 2304}
# {'token': 'ک', 'start_ms': 1630, 'end_ms': 1690, 'p': 0.976073, 'id': 6007}
# {'token': 'ن', 'start_ms': 1690, 'end_ms': 1830, 'p': 0.930699, 'id': 1863}
# {'token': ' است', 'start_ms': 1830, 'end_ms': 2260, 'p': 0.308057, 'id': 44713}
# {'token': ' ا', 'start_ms': 2260, 'end_ms': 2400, 'p': 0.980116, 'id': 1975}
# {'token': 'ت', 'start_ms': 2400, 'end_ms': 2440, 'p': 0.87246, 'id': 2655}
# {'token': 'ف', 'start_ms': 2550, 'end_ms': 2670, 'p': 0.747351, 'id': 5172}
# {'token': 'ا', 'start_ms': 2740, 'end_ms': 2820, 'p': 0.904825, 'id': 995}
# {'token': 'ق', 'start_ms': 2820, 'end_ms': 2950, 'p': 0.974814, 'id': 4587}
# {'token': ' ب', 'start_ms': 2960, 'end_ms': 3100, 'p': 0.928991, 'id': 4724}
# {'token': 'ی', 'start_ms': 3100, 'end_ms': 3230, 'p': 0.931409, 'id': 4135}
# {'token': 'وف', 'start_ms': 3390, 'end_ms': 3530, 'p': 0.334407, 'id': 38688}
# {'token': 'ت', 'start_ms': 3530, 'end_ms': 3610, 'p': 0.799818, 'id': 2655}
# {'token': 'د', 'start_ms': 3680, 'end_ms': 3810, 'p': 0.550329, 'id': 3215}
# {'token': ' و', 'start_ms': 3810, 'end_ms': 3910, 'p': 0.961736, 'id': 4032}
# {'token': ' خ', 'start_ms': 3950, 'end_ms': 4050, 'p': 0.913394, 'id': 16490}
# {'token': 'ط', 'start_ms': 4120, 'end_ms': 4230, 'p': 0.628983, 'id': 9566}
# {'token': 'ر', 'start_ms': 4230, 'end_ms': 4370, 'p': 0.976803, 'id': 2288}
# {'token': ' آ', 'start_ms': 4370, 'end_ms': 4510, 'p': 0.513907, 'id': 19753}
# {'token': 'ن', 'start_ms': 4510, 'end_ms': 4650, 'p': 0.997493, 'id': 1863}
# {'token': ' ه', 'start_ms': 4650, 'end_ms': 4790, 'p': 0.442675, 'id': 8032}
# {'token': 'م', 'start_ms': 4790, 'end_ms': 4860, 'p': 0.993663, 'id': 2304}
# {'token': 'ک', 'start_ms': 4960, 'end_ms': 5070, 'p': 0.482798, 'id': 6007}
# {'token': 'م', 'start_ms': 5070, 'end_ms': 5210, 'p': 0.861934, 'id': 2304}
# {'token': ' ن', 'start_ms': 5210, 'end_ms': 5350, 'p': 0.78262, 'id': 8717}
# {'token': 'ی', 'start_ms': 5350, 'end_ms': 5470, 'p': 0.97273, 'id': 4135}
# {'token': 'ست', 'start_ms': 5470, 'end_ms': 5730, 'p': 0.977868, 'id': 14851}
# {'token': '،', 'start_ms': 6130, 'end_ms': 6130, 'p': 0.32515, 'id': 12399}
# {'token': ' ا', 'start_ms': 6260, 'end_ms': 6260, 'p': 0.570662, 'id': 1975}
# {'token': 'ین', 'start_ms': 6290, 'end_ms': 6520, 'p': 0.937972, 'id': 32151}
